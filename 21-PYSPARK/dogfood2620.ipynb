# %%
import pyspark
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = sqlContext.sql('SELECT * from dog_food_csv2620')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+----+----+----+-------+
#    A|   B|   C|   D|Spoiled|
# +----+----+----+----+-------+
#  4.0| 2.0|12.0| 3.0|    1.0|
#  5.0| 6.0|12.0| 7.0|    1.0|
#  6.0| 2.0|13.0| 6.0|    1.0|
#  4.0| 2.0|12.0| 1.0|    1.0|
#  4.0| 2.0|12.0| 3.0|    1.0|
# 10.0| 3.0|13.0| 9.0|    1.0|
#  8.0| 5.0|14.0| 5.0|    1.0|
#  5.0| 8.0|12.0| 8.0|    1.0|
#  6.0| 5.0|12.0| 9.0|    1.0|
#  3.0| 3.0|12.0| 1.0|    1.0|
#  9.0| 8.0|11.0| 3.0|    1.0|
#  1.0|10.0|12.0| 3.0|    1.0|
#  1.0| 5.0|13.0|10.0|    1.0|
#  2.0|10.0|12.0| 6.0|    1.0|
#  1.0|10.0|11.0| 4.0|    1.0|
#  5.0| 3.0|12.0| 2.0|    1.0|
#  4.0| 9.0|11.0| 8.0|    1.0|
#  5.0| 1.0|11.0| 1.0|    1.0|
#  4.0| 9.0|12.0|10.0|    1.0|
#  5.0| 8.0|10.0| 9.0|    1.0|
# +----+----+----+----+-------+
# only showing top 20 rows
#
# </div>

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- A: float (nullable = true)
# -- B: float (nullable = true)
# -- C: float (nullable = true)
# -- D: float (nullable = true)
# -- Spoiled: float (nullable = true)
#
# </div>

# %%
from pyspark.ml.feature import VectorAssembler
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
assembler = VectorAssembler(inputCols=['A','B','C','D'],outputCol='features')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
assembler
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: VectorAssembler_6514c5829b0f</div>

# %%
outputput
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: DataFrame[A: float, B: float, C: float, D: float, Spoiled: float, features: vector]</div>

# %%
outputput.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+----+----+----+-------+-------------------+
#    A|   B|   C|   D|Spoiled|           features|
# +----+----+----+----+-------+-------------------+
#  4.0| 2.0|12.0| 3.0|    1.0| [4.0,2.0,12.0,3.0]|
#  5.0| 6.0|12.0| 7.0|    1.0| [5.0,6.0,12.0,7.0]|
#  6.0| 2.0|13.0| 6.0|    1.0| [6.0,2.0,13.0,6.0]|
#  4.0| 2.0|12.0| 1.0|    1.0| [4.0,2.0,12.0,1.0]|
#  4.0| 2.0|12.0| 3.0|    1.0| [4.0,2.0,12.0,3.0]|
# 10.0| 3.0|13.0| 9.0|    1.0|[10.0,3.0,13.0,9.0]|
#  8.0| 5.0|14.0| 5.0|    1.0| [8.0,5.0,14.0,5.0]|
#  5.0| 8.0|12.0| 8.0|    1.0| [5.0,8.0,12.0,8.0]|
#  6.0| 5.0|12.0| 9.0|    1.0| [6.0,5.0,12.0,9.0]|
#  3.0| 3.0|12.0| 1.0|    1.0| [3.0,3.0,12.0,1.0]|
#  9.0| 8.0|11.0| 3.0|    1.0| [9.0,8.0,11.0,3.0]|
#  1.0|10.0|12.0| 3.0|    1.0|[1.0,10.0,12.0,3.0]|
#  1.0| 5.0|13.0|10.0|    1.0|[1.0,5.0,13.0,10.0]|
#  2.0|10.0|12.0| 6.0|    1.0|[2.0,10.0,12.0,6.0]|
#  1.0|10.0|11.0| 4.0|    1.0|[1.0,10.0,11.0,4.0]|
#  5.0| 3.0|12.0| 2.0|    1.0| [5.0,3.0,12.0,2.0]|
#  4.0| 9.0|11.0| 8.0|    1.0| [4.0,9.0,11.0,8.0]|
#  5.0| 1.0|11.0| 1.0|    1.0| [5.0,1.0,11.0,1.0]|
#  4.0| 9.0|12.0|10.0|    1.0|[4.0,9.0,12.0,10.0]|
#  5.0| 8.0|10.0| 9.0|    1.0| [5.0,8.0,10.0,9.0]|
# +----+----+----+----+-------+-------------------+
# only showing top 20 rows
#
# </div>

# %%
from pyspark.ml.classification import RandomForestClassifier
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rfc = RandomForestClassifier(labelCol='Spoiled',featuresCol='features')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rfc
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: RandomForestClassifier_c1efbedb8f7e</div>

# %%
final_data = outputput.select('features','Spoiled')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rfc_model = rfc.fit(final_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rfc_model.featureImportances
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: SparseVector(4, {0: 0.0224, 1: 0.018, 2: 0.9413, 3: 0.0183})</div>

# %%
0: 0.0224, 1: 0.018, 2: 0.9413, 3: 0.0183
        
        A        B        C          D
