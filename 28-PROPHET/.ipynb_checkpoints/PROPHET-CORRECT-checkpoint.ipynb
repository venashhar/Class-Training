# %%
import pandas as pd
from fbprophet import Prophet
# %matplotlib inline

# %%
pwd
# Out:
# 'C:\\Users\\hari\\Google Drive\\3-AWS_bigdata\\Training\\28-PROPHET'

# %%
df = pd.read_csv('HospitalityEmployees.csv')

# %%
df.columns = ['ds','y']
df['ds'] = pd.to_datetime(df['ds'])

# %%
df.plot(x='ds',y='y',figsize=(12,8),label='Employees')

# %%
len(df)
# Out:
# 348

# %%
len(df) - 12
# Out:
# 336

# %%
train = df.iloc[:336]
test = df.iloc[336:]

# %%
m = Prophet()
m.fit(train)
future = m.make_future_dataframe(periods=12,freq='M')
forecast = m.predict(future)

#MS - First of Month

# H - Hour
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast
# Out:
#             ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0   1990-01-01  1104.895951  1049.325435  1067.475671  1104.895951
# 1   1990-02-01  1105.589015  1065.080524  1082.133397  1105.589015
# 2   1990-03-01  1106.215008  1079.952262  1097.721131  1106.215008
# 3   1990-04-01  1106.908073  1095.985359  1113.738210  1106.908073
# 4   1990-05-01  1107.578780  1111.680741  1130.105983  1107.578780
# ..         ...          ...          ...          ...          ...
# 343 2018-07-31  2046.699177  2064.096008  2085.454007  2041.796507
# 344 2018-08-31  2052.822097  2056.925215  2081.006358  2046.688420
# 345 2018-09-30  2058.747502  2042.266671  2065.850403  2051.533678
# 346 2018-10-31  2064.870422  2039.038599  2065.822670  2056.051050
# 347 2018-11-30  2070.795827  2049.900159  2077.360475  2060.245642
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0    1104.895951      -46.170704            -46.170704            -46.170704
# 1    1105.589015      -31.860980            -31.860980            -31.860980
# 2    1106.215008      -17.400218            -17.400218            -17.400218
# 3    1106.908073       -2.243272             -2.243272             -2.243272
# 4    1107.578780       14.076414             14.076414             14.076414
# ..           ...             ...                   ...                   ...
# 343  2051.157079       28.254542             28.254542             28.254542
# 344  2058.954738       15.823811             15.823811             15.823811
# 345  2066.310821       -4.664657             -4.664657             -4.664657
# 346  2073.616420      -11.885307            -11.885307            -11.885307
# 347  2081.142715       -7.487576             -7.487576             -7.487576
#
#         yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0   -46.170704    -46.170704    -46.170704                   0.0
# 1   -31.860980    -31.860980    -31.860980                   0.0
# 2   -17.400218    -17.400218    -17.400218                   0.0
# 3    -2.243272     -2.243272     -2.243272                   0.0
# 4    14.076414     14.076414     14.076414                   0.0
# ..         ...           ...           ...                   ...
# 343  28.254542     28.254542     28.254542                   0.0
# 344  15.823811     15.823811     15.823811                   0.0
# 345  -4.664657     -4.664657     -4.664657                   0.0
# 346 -11.885307    -11.885307    -11.885307                   0.0
# 347  -7.487576     -7.487576     -7.487576                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 0                           0.0                         0.0  1058.725248
# 1                           0.0                         0.0  1073.728035
# 2                           0.0                         0.0  1088.814791
# 3                           0.0                         0.0  1104.664801
# 4                           0.0                         0.0  1121.655193
# ..                          ...                         ...          ...
# 343                         0.0                         0.0  2074.953720
# 344                         0.0                         0.0  2068.645908
# 345                         0.0                         0.0  2054.082845
# 346                         0.0                         0.0  2052.985115
# 347                         0.0                         0.0  2063.308252
#
# [348 rows x 16 columns]

# %%
from fbprophet.plot import add_changepoints_to_plot
fig = m.plot(forecast)

# %%
m.plot_components(forecast)

# %%
df1= forecast[forecast['ds'] > '2018-01-01]
# Out:
#   File "<ipython-input-24-bc7478de5ac9>", line 1
#     df1= forecast[forecast['ds'] > '2018-01-01]
#                                                ^
# SyntaxError: EOL while scanning string literal

# %%
df1
# Out:
# Empty DataFrame
# Columns: [ds, trend, yhat_lower, yhat_upper, trend_lower, trend_upper, additive_terms, additive_terms_lower, additive_terms_upper, yearly, yearly_lower, yearly_upper, multiplicative_terms, multiplicative_terms_lower, multiplicative_terms_upper, yhat]
# Index: []

# %%
test
# Out:
#             ds       y
# 336 2018-01-01  1916.8
# 337 2018-02-01  1944.5
# 338 2018-03-01  1962.2
# 339 2018-04-01  1984.9
# 340 2018-05-01  2001.5
# 341 2018-06-01  2015.3
# 342 2018-07-01  2022.1
# 343 2018-08-01  2019.1
# 344 2018-09-01  1992.5
# 345 2018-10-01  1984.3
# 346 2018-11-01  1990.1
# 347 2018-12-01  2000.2

# %% [markdown]
# # ADVANTAGE

# %% [raw]
# Ability to easily model any number of seasonalities
# Ability to work with missing dates in time-series
# Easily integrates holidays in the model

# %% [markdown]
# # DISADVANTAGE

# %% [raw]
# Can be volatile with a low number of observations
# Long-horizon forecasting can be volatile with automatic changepoint selection
