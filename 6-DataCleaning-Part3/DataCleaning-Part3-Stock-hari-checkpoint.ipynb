# %%
import pandas as pd

# %%
df = pd.read_csv('stock.csv')

# %%
df
# Out:
#             SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST  \
# 0        20MICRONS     EQ     37.80     37.80     36.15     36.85     37.40
# 1       3IINFOTECH     EQ      4.10      4.85      4.00      4.55      4.65
# 2          3MINDIA     EQ  13425.15  13469.55  12920.00  13266.70  13300.00
# 3          63MOONS     EQ     61.00     61.90     60.35     61.00     61.10
# 4          8KMILES     EQ    546.10    548.00    535.00    537.45    535.20
# ...            ...    ...       ...       ...       ...       ...       ...
# 846399        ZOTA     SM    221.00    221.00    214.00    217.00    217.00
# 846400       ZUARI     EQ    562.00    562.00    549.55    550.80    552.00
# 846401   ZUARIGLOB     EQ    255.50    258.40    252.50    253.25    253.00
# 846402   ZYDUSWELL     EQ   1038.00   1068.00   1033.00   1043.20   1035.00
# 846403       ZYLOG     EQ      4.30      5.15      4.30      4.65      4.60
#
# ...

# %%
df = pd.read_csv('stock.csv',index_col='TIMESTAMP')

# %%
df
# Out:
#                 SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE  \
# TIMESTAMP
# 2017-06-28   20MICRONS     EQ     37.80     37.80     36.15     36.85
# 2017-06-28  3IINFOTECH     EQ      4.10      4.85      4.00      4.55
# 2017-06-28     3MINDIA     EQ  13425.15  13469.55  12920.00  13266.70
# 2017-06-28     63MOONS     EQ     61.00     61.90     60.35     61.00
# 2017-06-28     8KMILES     EQ    546.10    548.00    535.00    537.45
# ...                ...    ...       ...       ...       ...       ...
# 2017-12-29        ZOTA     SM    221.00    221.00    214.00    217.00
# 2017-12-29       ZUARI     EQ    562.00    562.00    549.55    550.80
# 2017-12-29   ZUARIGLOB     EQ    255.50    258.40    252.50    253.25
# 2017-12-29   ZYDUSWELL     EQ   1038.00   1068.00   1033.00   1043.20
# 2017-12-29       ZYLOG     EQ      4.30      5.15      4.30      4.65
#
#                 LAST  PREVCLOSE  TOTTRDQTY    TOTTRDVAL  TOTALTRADES  \
# TIMESTAMP
# ...

# %%
df.groupby("SYMBOL")

# %%
symbol = df.groupby("SYMBOL")

# %%
symbol

# %%
symbol.size()
# Out:
# SYMBOL
# 20MICRONS     495
# 3IINFOTECH    495
# 3MINDIA       495
# 549            49
# 5PAISA         31
#              ...
# ZOTA          162
# ZUARI         495
# ZUARIGLOB     495
# ZYDUSWELL     495
# ZYLOG         494
# Length: 2037, dtype: int64

# %%
open = df.groupby("OPEN")

# %%
open.size()
# Out:
# OPEN
# 0.05         317
# 0.10         646
# 0.15         679
# 0.20         893
# 0.25         912
#             ...
# 115500.00      1
# 117200.00      1
# 119000.00      1
# 119500.00      1
# 119990.00      1
# Length: 58241, dtype: int64

# %%
open.first()
# Out:
#               SYMBOL SERIES       HIGH        LOW      CLOSE       LAST  \
# OPEN
# 0.05        BIRLACOT     BE       0.10       0.05       0.10       0.10
# 0.10       FARMAXIND     EQ       0.15       0.10       0.10       0.10
# 0.15         AUSTRAL     BE       0.20       0.15       0.20       0.20
# 0.20       KSERASERA     EQ       0.20       0.10       0.15       0.15
# 0.25         FCSSOFT     EQ       0.25       0.20       0.25       0.25
# ...              ...    ...        ...        ...        ...        ...
# 115500.00        PEL     D1  115650.00  115500.00  115650.00  115650.00
# 117200.00        PEL     D1  117200.00  116700.00  116700.00  116700.00
# 119000.00        PEL     D1  119000.00  119000.00  119000.00  119000.00
# 119500.00        PEL     D1  119500.00  113000.00  113000.00  113000.00
# 119990.00        PEL     D1  119990.00  119990.00  119990.00  119990.00
#
#            PREVCLOSE  TOTTRDQTY    TOTTRDVAL  TOTALTRADES          ISIN
# OPEN
# ...

# %%
open.groups
# Out:
# {0.05: Index(['2017-02-28', '2017-03-20', '2017-03-28', '2017-05-08', '2017-05-08',
#         '2017-01-31', '2017-01-31', '2017-03-27', '2017-09-04', '2017-09-04',
#         ...
#         '2016-02-15', '2016-08-23', '2016-08-23', '2016-10-17', '2016-02-08',
#         '2016-07-20', '2016-11-08', '2016-03-15', '2016-04-08', '2016-04-08'],
#        dtype='object', name='TIMESTAMP', length=317),
#  0.1: Index(['2017-02-28', '2017-02-28', '2017-02-28', '2017-03-20', '2017-01-23',
#         '2017-01-23', '2017-01-23', '2017-01-23', '2017-03-28', '2017-08-03',
#         ...
#         '2016-06-08', '2016-06-08', '2016-06-08', '2016-03-15', '2016-03-15',
#         '2016-04-08', '2016-09-23', '2016-09-23', '2016-09-23', '2016-09-23'],
#        dtype='object', name='TIMESTAMP', length=646),
#  0.15: Index(['2017-06-28', '2017-06-28', '2017-06-28', '2017-11-28', '2017-04-28',
#         '2017-04-28', '2017-04-28', '2017-03-20', '2017-05-12', '2017-04-20',
#         ...
# ...

# %%
df3 = df.iloc[:,6]

# %%
df3
# Out:
# TIMESTAMP
# 2017-06-28       37.40
# 2017-06-28        4.65
# 2017-06-28    13300.00
# 2017-06-28       61.10
# 2017-06-28      535.20
#                 ...
# 2017-12-29      217.00
# 2017-12-29      552.00
# 2017-12-29      253.00
# 2017-12-29     1035.00
# 2017-12-29        4.60
# Name: LAST, Length: 846404, dtype: float64

# %%
symbol.get_group("ZOTA")
# Out:
#            SERIES    OPEN    HIGH     LOW   CLOSE    LAST  PREVCLOSE  \
# TIMESTAMP
# 2017-06-28     SM  132.50  132.75  132.35  132.35  132.35     132.35
# 2017-11-28     SM  208.00  212.00  207.80  210.30  210.30     208.00
# 2017-05-12     SM  127.15  128.35  127.00  127.25  127.05     127.00
# 2017-08-16     SM  131.50  132.00  131.25  131.30  131.30     132.00
# 2017-08-03     SM  133.15  133.40  132.80  133.00  133.00     133.10
# ...           ...     ...     ...     ...     ...     ...        ...
# 2017-11-14     SM  195.50  195.75  190.50  191.00  191.00     197.35
# 2017-08-22     SM  131.50  133.50  131.25  132.00  132.00     131.00
# 2017-12-04     SM  222.00  222.20  212.25  220.00  220.25     218.55
# 2017-12-11     SM  220.00  220.90  220.00  220.00  220.00     215.10
# 2017-12-29     SM  221.00  221.00  214.00  217.00  217.00     220.00
#
#             TOTTRDQTY   TOTTRDVAL  TOTALTRADES          ISIN  symbol
# TIMESTAMP
# ...

# %%
df["symbol"] = "symbol"

# %%
df[df["symbol"] == "symbol"]
# Out:
#                 SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE  \
# TIMESTAMP
# 2017-06-28   20MICRONS     EQ     37.80     37.80     36.15     36.85
# 2017-06-28  3IINFOTECH     EQ      4.10      4.85      4.00      4.55
# 2017-06-28     3MINDIA     EQ  13425.15  13469.55  12920.00  13266.70
# 2017-06-28     63MOONS     EQ     61.00     61.90     60.35     61.00
# 2017-06-28     8KMILES     EQ    546.10    548.00    535.00    537.45
# ...                ...    ...       ...       ...       ...       ...
# 2017-12-29        ZOTA     SM    221.00    221.00    214.00    217.00
# 2017-12-29       ZUARI     EQ    562.00    562.00    549.55    550.80
# 2017-12-29   ZUARIGLOB     EQ    255.50    258.40    252.50    253.25
# 2017-12-29   ZYDUSWELL     EQ   1038.00   1068.00   1033.00   1043.20
# 2017-12-29       ZYLOG     EQ      4.30      5.15      4.30      4.65
#
#                 LAST  PREVCLOSE  TOTTRDQTY    TOTTRDVAL  TOTALTRADES  \
# TIMESTAMP
# ...

# %%
symbol.max()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-69-40d626f44257> in <module>
# ----> 1 symbol.max()
#
# C:\python\INSTALL\ANACONDA\lib\site-packages\pandas\core\groupby\groupby.py in f(self, **kwargs)
#    1376                 # try a cython aggregation if we can
#    1377                 try:
# -> 1378                     return self._cython_agg_general(alias, alt=npfunc, **kwargs)
#    1379                 except DataError:
#    1380                     pass
#
# C:\python\INSTALL\ANACONDA\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1002     ) -> DataFrame:
#    1003         agg_blocks, agg_items = self._cython_agg_blocks(
# -> 1004             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#    1005         )
# ...

# %% [markdown]
# symbol

# %%
symbol.sum()
# Out:
#                   OPEN        HIGH         LOW       CLOSE        LAST  \
# SYMBOL
# 20MICRONS     18502.10    18974.50    17958.05    18368.85    18372.15
# 3IINFOTECH     2415.30     2473.05     2345.05     2394.50     2403.65
# 3MINDIA     6355447.80  6434010.90  6255761.50  6334191.50  6334249.20
# 549             565.61      568.02      564.11      566.52      566.52
# 5PAISA         9039.25     9147.50     8955.80     9008.65     8995.00
# ...                ...         ...         ...         ...         ...
# ZOTA          25405.85    25671.40    25102.60    25327.90    25339.20
# ZUARI        148131.10   152264.85   144776.60   147908.90   147833.10
# ZUARIGLOB     61257.45    62790.20    59936.60    61141.05    61132.80
# ZYDUSWELL    415820.80   421563.65   410245.55   414916.90   414886.35
# ZYLOG          2039.80     2109.65     1976.15     2036.25     2042.25
#
#              PREVCLOSE   TOTTRDQTY     TOTTRDVAL  TOTALTRADES
# SYMBOL
# ...

# %%
symbol.get_group("20MICRONS").sum()
# Out:
# SERIES         EQEQEQEQEQEQEQEQEQEQEQEQEQEQEQEQEQEQEQEQEQEQEQ...
# OPEN                                                     18502.1
# HIGH                                                     18974.5
# LOW                                                      17958.1
# CLOSE                                                    18368.8
# LAST                                                     18372.1
# PREVCLOSE                                                18347.1
# TOTTRDQTY                                               73057227
# TOTTRDVAL                                            3.21012e+09
# TOTALTRADES                                               404565
# ISIN           INE144J01027INE144J01027INE144J01027INE144J010...
# symbol         symbolsymbolsymbolsymbolsymbolsymbolsymbolsymb...
# dtype: object

# %%
symbol.get_group("20MICRONS").mean()
# Out:
# OPEN           3.737798e+01
# HIGH           3.833232e+01
# LOW            3.627889e+01
# CLOSE          3.710879e+01
# LAST           3.711545e+01
# PREVCLOSE      3.706475e+01
# TOTTRDQTY      1.475904e+05
# TOTTRDVAL      6.485095e+06
# TOTALTRADES    8.173030e+02
# dtype: float64

# %%
symbol["PREVCLOSE"].sum()
# Out:
# SYMBOL
# 20MICRONS       18347.05
# 3IINFOTECH       2391.35
# 3MINDIA       6326462.60
# 549               560.27
# 5PAISA           9248.05
#                  ...
# ZOTA            25235.90
# ZUARI          147516.65
# ZUARIGLOB       60991.95
# ZYDUSWELL      414737.60
# ZYLOG            2035.85
# Name: PREVCLOSE, Length: 2037, dtype: float64

# %%
symbol["PREVCLOSE"].max()
# Out:
# SYMBOL
# 20MICRONS        62.70
# 3IINFOTECH        7.30
# 3MINDIA       19366.40
# 549              17.10
# 5PAISA          615.45
#                 ...
# ZOTA            221.00
# ZUARI           646.70
# ZUARIGLOB       316.40
# ZYDUSWELL      1023.10
# ZYLOG             6.95
# Name: PREVCLOSE, Length: 2037, dtype: float64

# %%
symbol[["OPEN","HIGH"]].mean()
# Out:
#                     OPEN          HIGH
# SYMBOL
# 20MICRONS      37.377980     38.332323
# 3IINFOTECH      4.879394      4.996061
# 3MINDIA     12839.288485  12998.001818
# 549            11.543061     11.592245
# 5PAISA        291.588710    295.080645
# ...                  ...           ...
# ZOTA          156.826235    158.465432
# ZUARI         299.254747    307.605758
# ZUARIGLOB     123.752424    126.848889
# ZYDUSWELL     840.042020    851.643737
# ZYLOG           4.129150      4.270547
#
# [2037 rows x 2 columns]

# %%
df = pd.read_csv("stock.csv",index_col="SYMBOL")

# %%
symbol = df.groupby(["OPEN","CLOSE"])

# %%
symbol.size()
# Out:
# OPEN       CLOSE
# 0.05       0.05         185
#            0.10         128
#            0.15           4
# 0.10       0.05          86
#            0.10         425
#                        ...
# 115500.00  115650.00      1
# 117200.00  116700.00      1
# 119000.00  119000.00      1
# 119500.00  113000.00      1
# 119990.00  119990.00      1
# Length: 556426, dtype: int64
