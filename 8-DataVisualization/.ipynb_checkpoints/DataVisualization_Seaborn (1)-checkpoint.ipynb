# %%
import pandas as pd

# %%
#https://stackoverflow.com/questions/51666784/what-is-y-axis-in-seaborn-distplot

# %%
df = pd.read_csv('tips.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  244 non-null    int64
#  1   total_bill  244 non-null    float64
#  2   tip         244 non-null    float64
#  3   sex         244 non-null    object
#  4   smoker      244 non-null    object
#  5   day         244 non-null    object
#  6   time        244 non-null    object
#  7   size        244 non-null    int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 15.4+ KB

# %%
import seaborn as sns

# %%
sns.distplot(df.total_bill,bins=5)

# %%
sns.distplot(df.tip)

# %%
sns.distplot(df.tip)

# %%
sns.distplot(df.tip, bins=12)

# %%
sns.distplot(df.total_bill,bins=10)

# %%
sns.distplot(df.total_bill,bins=10,color='red')

# %%
sns.distplot(df.total_bill,bins=10,color='red')

#tip  bin 5   color blue

# %%
sns.distplot(df.tip,bins=5,color='blue')

# %%
sns.distplot(df.total_bill,bins=10,kde=False,color='blue',hist_kws=dict(edgecolor="k", linewidth=3))

# %%
sns.boxplot(x='day',y='total_bill',data=df)

# %%
sns.boxplot(x='smoker',y='tip',data=df)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size'],
#       dtype='object')

# %%
px.box(df,x='day',y='total_bill')
# Out:
# <div>
#
#
#             <div id="a9b8c002-08a8-4826-9fa8-1238476183fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a9b8c002-08a8-4826-9fa8-1238476183fc")) {
#                     Plotly.newPlot(
#                         'a9b8c002-08a8-4826-9fa8-1238476183fc',
# ...

# %%
sns.boxplot(x='smoker',y='tip',data=df)

# %%
sns.boxplot(x='time',y='total_bill',data=df)

# %%
sns.boxplot(x='time',y='total_bill',data=df)

# %%
#sns.boxplot(x='time',y='total_bill',data=df)
df.columns
# Out:
# Index(['Unnamed: 0', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size'],
#       dtype='object')

# %%
sns.boxplot(x='day',y='total_bill',hue='smoker',data=df,linewidth=2.5)

# %%
sns.boxplot(x='sex',y='tip',hue = 'sex',data=df)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size'],
#       dtype='object')

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
sns.boxplot(x='day',y='tip',data=df,order=['Sun', 'Sat', 'Thur', 'Fri'])

# %%
sns.boxplot(x='sex',y='tip',data=df,order=['Male','Female'])

# %%
sns.boxplot(x='time',y='tip',hue='day',data=df)

# %%
sns.boxplot(x='time',y='tip',data=df)
sns.swarmplot(x='time',y='tip',data=df,color='0.25')

# %%
sns.catplot(x='sex',y='total_bill',hue='smoker',col='time',data=df,kind='box')

# %%
sns.violinplot(x='sex',y='total_bill',hue='smoker',data = df)

# %%
sns.violinplot(x='sex',y='total_bill',data=df)
sns.swarmplot(x='sex',y='total_bill',data=df,color='yellow')

# %%
sns.violinplot(x='sex',y='total_bill',data=df)

# %%
pd.read_csv
pd.write_csv(r'C:\Users\hp\OneDrive\Personnel\Newfile.csv')

# %%
pwd
# Out:
# 'C:\\Users\\hp'
